# %%
import pandas as pd

# %%
data = pd.read_csv("/content/BBC News.csv")

# %%
#data exploration

# %%
#what is in the data
data.head()
# Out:
#    ArticleId                                               Text  Category
# 0       1833  worldcom ex-boss launches defence lawyers defe...  business
# 1        154  german business confidence slides german busin...  business
# 2       1101  bbc poll indicates economic gloom citizens in ...  business
# 3       1976  lifestyle  governs mobile choice  faster  bett...      tech
# 4        917  enron bosses in $168m payout eighteen former e...  business

# %%
data['Category'].value_counts()
# Out:
# sport            346
# business         336
# politics         274
# entertainment    273
# tech             261
# Name: Category, dtype: int64

# %%
data.shape
# Out:
# (1490, 3)

# %%
data.isnull().any()
# Out:
# ArticleId    False
# Text         False
# Category     False
# dtype: bool

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1490 entries, 0 to 1489
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ArticleId  1490 non-null   int64
#  1   Text       1490 non-null   object
#  2   Category   1490 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 35.0+ KB

# %%
import seaborn as sns

# %%
sns.countplot(data['Category'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#drop article id
data = data.drop('ArticleId', axis=1)

# %%
data.head()
# Out:
#                                                 Text  Category
# 0  worldcom ex-boss launches defence lawyers defe...  business
# 1  german business confidence slides german busin...  business
# 2  bbc poll indicates economic gloom citizens in ...  business
# 3  lifestyle  governs mobile choice  faster  bett...      tech
# 4  enron bosses in $168m payout eighteen former e...  business

# %%
#Length (character length) of text column
data['text_length'] = data['Text'].str.len()
data.head()
# Out:
#                                                 Text  Category  text_length
# 0  worldcom ex-boss launches defence lawyers defe...  business         1866
# 1  german business confidence slides german busin...  business         2016
# 2  bbc poll indicates economic gloom citizens in ...  business         3104
# 3  lifestyle  governs mobile choice  faster  bett...      tech         3618
# 4  enron bosses in $168m payout eighteen former e...  business         2190

# %%
sns.distplot(data['text_length'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#WORDCLOUD
data.head()
# Out:
#                                                 Text  Category  text_length
# 0  worldcom ex-boss launches defence lawyers defe...  business         1866
# 1  german business confidence slides german busin...  business         2016
# 2  bbc poll indicates economic gloom citizens in ...  business         3104
# 3  lifestyle  governs mobile choice  faster  bett...      tech         3618
# 4  enron bosses in $168m payout eighteen former e...  business         2190

# %%
data['Category'].value_counts()
# Out:
# sport            346
# business         336
# politics         274
# entertainment    273
# tech             261
# Name: Category, dtype: int64

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
#word cloud for category sport
#extract all the text corresponding to sport category

temp_df = data[data['Category'] == 'sport']
sport_sentences = temp_df['Text'].tolist()
print(len(sport_sentences))
sport_sentences = " ".join(sport_sentences)
#sport_sentences

wordcloud = WordCloud().generate(sport_sentences)
plt.imshow(wordcloud)
# Out:
# 346

# %%
#word cloud for category business
#extract all the text corresponding to business category

temp_df = data[data['Category'] == 'business']
business_sentences = temp_df['Text'].tolist()
print(len(business_sentences))
business_sentences = " ".join(business_sentences)
#business_sentences

wordcloud = WordCloud().generate(business_sentences)
plt.imshow(wordcloud)
# Out:
# 336

# %%
#word cloud for category tech
#extract all the text corresponding to tech category

temp_df = data[data['Category'] == 'tech']
tech_sentences = temp_df['Text'].tolist()
print(len(tech_sentences))
tech_sentences = " ".join(tech_sentences)
#sport_sentences

wordcloud = WordCloud().generate(tech_sentences)
plt.imshow(wordcloud)
# Out:
# 261

# %%
#word cloud for category politics
#extract all the text corresponding to politics category

temp_df = data[data['Category'] == 'politics']
politics_sentences = temp_df['Text'].tolist()
print(len(politics_sentences))
politics_sentences = " ".join(politics_sentences)
#sport_sentences

wordcloud = WordCloud().generate(politics_sentences)
plt.imshow(wordcloud)
# Out:
# 274

# %%
#word cloud for category entertainment
#extract all the text corresponding to tech category

temp_df = data[data['Category'] == 'entertainment']
entertainment_sentences = temp_df['Text'].tolist()
print(len(entertainment_sentences))
entertainment_sentences = " ".join(entertainment_sentences)
#sport_sentences

wordcloud = WordCloud().generate(entertainment_sentences)
plt.imshow(wordcloud)
# Out:
# 273

# %%
#Data preprocessing or cleaning
#remove punctuations and stop words
#make all the text normalized (mmake it lower)

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
mystopwords = set(stopwords.words('english'))
print(mystopwords)
# Out:
# {'ve', 'wasn', 'ourselves', 'most', 'have', 'while', 'there', 'ours', "don't", 'he', 'didn', "isn't", 'then', 'on', "she's", 'below', 'i', 'all', "that'll", 'before', 'yourself', 'to', 'his', 'again', 'y', 'has', 'both', 'were', "you'd", 'they', 'not', 'but', 'hers', 'their', 'when', 're', 'until', 'once', 'ma', 'only', "doesn't", "wouldn't", 'o', 'that', 'been', 'where', 'mustn', 'you', 'above', 'down', 'own', 'so', "mightn't", 'those', 'our', 'can', 'after', 'had', 'd', 'now', "haven't", 'him', 'how', 'couldn', "should've", 'ain', 'mightn', 'by', "shouldn't", 'do', 'for', 'whom', 'yourselves', 'doesn', 'don', 'because', 'why', 'what', "mustn't", 'wouldn', 'same', 'about', 'isn', "won't", "you're", 'is', "you've", 'them', 'than', 'and', 'my', 'theirs', 'here', 'haven', 'll', 'she', "weren't", 'of', 'such', 'm', 'over', 'against', 'having', 'myself', 'between', 'your', 'an', 'few', 'nor', "didn't", "needn't", 'just', 'himself', 'needn', 'no', "hasn't", 'more', 'a', 'was', 'are', 'at'
# ...

# %%
def preprocess_text(text):
  text = text.lower()
  mystopwords = set(stopwords.words('english'))
  word_tokenize_output = word_tokenize(text)

  temp_word_list = []

  for each_word in word_tokenize_output:
    if each_word in mystopwords:
      pass
    else:
      temp_word_list.append(each_word)

  temp_word_list = " ".join(temp_word_list)
  return temp_word_list

# %%
data.head()
# Out:
#                                                 Text  Category  text_length
# 0  worldcom ex-boss launches defence lawyers defe...  business         1866
# 1  german business confidence slides german busin...  business         2016
# 2  bbc poll indicates economic gloom citizens in ...  business         3104
# 3  lifestyle  governs mobile choice  faster  bett...      tech         3618
# 4  enron bosses in $168m payout eighteen former e...  business         2190

# %%
data['cleaned_text'] = data['Text'].apply(preprocess_text)

# %%
data.head()
# Out:
#                                                 Text  ...                                       cleaned_text
# 0  worldcom ex-boss launches defence lawyers defe...  ...  worldcom ex-boss launches defence lawyers defe...
# 1  german business confidence slides german busin...  ...  german business confidence slides german busin...
# 2  bbc poll indicates economic gloom citizens in ...  ...  bbc poll indicates economic gloom citizens maj...
# 3  lifestyle  governs mobile choice  faster  bett...  ...  lifestyle governs mobile choice faster better ...
# 4  enron bosses in $168m payout eighteen former e...  ...  enron bosses $ 168m payout eighteen former enr...
#
# [5 rows x 4 columns]

# %%
new_data = data[['cleaned_text', 'Category']]
#new_data.issnull().any()

# %%
new_data.head()

# %%
#Label encoding for target column- category
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
new_data['target'] = label_encoder.fit_transform(new_data['Category'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
new_data.head()
# Out:
#                                         cleaned_text  Category  target
# 0  worldcom ex-boss launches defence lawyers defe...  business       0
# 1  german business confidence slides german busin...  business       0
# 2  bbc poll indicates economic gloom citizens maj...  business       0
# 3  lifestyle governs mobile choice faster better ...      tech       4
# 4  enron bosses $ 168m payout eighteen former enr...  business       0

# %%
new_data = new_data[['cleaned_text', 'target']]
new_data.head()
# Out:
#                                         cleaned_text  target
# 0  worldcom ex-boss launches defence lawyers defe...       0
# 1  german business confidence slides german busin...       0
# 2  bbc poll indicates economic gloom citizens maj...       0
# 3  lifestyle governs mobile choice faster better ...       4
# 4  enron bosses $ 168m payout eighteen former enr...       0

# %%
#split the data into train and test
from sklearn.model_selection import train_test_split

features = new_data['cleaned_text']
target = new_data['target']

x_train, x_test, y_train, y_test = train_test_split(features, target, train_size=0.75, random_state=35)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1117,)
# (1117,)
# (373,)
# (373,)

# %%
#Apply TF-IDF vectorizataion on x_train and x_test
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(max_features=300)

features_train = tfidf.fit_transform(x_train).toarray()
features_test = tfidf.fit_transform(x_test).toarray()

# %%
print(features_train)
# Out:
# [[0.         0.         0.         ... 0.14737877 0.         0.14493735]
#  [0.         0.05906331 0.         ... 0.03630461 0.09789797 0.        ]
#  [0.         0.         0.         ... 0.1839463  0.         0.        ]
#  ...
#  [0.05994943 0.02521693 0.03041066 ... 0.07750082 0.07314527 0.01524339]
#  [0.         0.         0.09082914 ... 0.09259034 0.18725734 0.09105652]
#  [0.08044739 0.         0.         ... 0.10399996 0.         0.        ]]

# %%
features_train
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.14737877, 0.        ,
#         0.14493735],
#        [0.        , 0.05906331, 0.        , ..., 0.03630461, 0.09789797,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.1839463 , 0.        ,
#         0.        ],
#        ...,
#        [0.05994943, 0.02521693, 0.03041066, ..., 0.07750082, 0.07314527,
#         0.01524339],
#        [0.        , 0.        , 0.09082914, ..., 0.09259034, 0.18725734,
#         0.09105652],
#        [0.08044739, 0.        , 0.        , ..., 0.10399996, 0.        ,
#         0.        ]])

# %%
features_test
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.        , 0.27237297,
#         0.        ],
#        [0.11404942, 0.        , 0.        , ..., 0.        , 0.07683667,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.04751173, 0.02382896,
#         0.        ],
#        ...,
#        [0.06877733, 0.03772571, 0.        , ..., 0.0461941 , 0.1158406 ,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.05046763,
#         0.03630468],
#        [0.        , 0.        , 0.        , ..., 0.09324326, 0.09353017,
#         0.        ]])

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(features_train, y_train)
predictions = model.predict(features_test)

print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.45      0.80      0.58        79
#            1       0.23      0.14      0.17        64
#            2       0.82      0.43      0.57        74
#            3       0.44      0.52      0.47        87
#            4       0.47      0.36      0.41        69
#
#     accuracy                           0.47       373
#    macro avg       0.48      0.45      0.44       373
# weighted avg       0.49      0.47      0.45       373

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(features_train,y_train)
predictions = model.predict(features_test)

# %%
predictions

# %%
print(classification_report(y_test, predictions))

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(features_train, y_train)
predictions = model.predict(features_test)

print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.45      0.80      0.58        79
#            1       0.23      0.14      0.17        64
#            2       0.82      0.43      0.57        74
#            3       0.44      0.52      0.47        87
#            4       0.47      0.36      0.41        69
#
#     accuracy                           0.47       373
#    macro avg       0.48      0.45      0.44       373
# weighted avg       0.49      0.47      0.45       373
